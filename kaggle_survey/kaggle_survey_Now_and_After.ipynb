# %% [markdown]
# <a href="https://colab.research.google.com/github/jaaaamj0711/kaggle_study/blob/master/kaggle_survey/kaggle_survey_Now_and_After.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 kaggle survey 2020 (Now and After)

# %% [markdown]
# ## 💻 분석을 통한 인사이트 찾기

# %% [markdown]
# 캐글 설문지에서는 캐글러들에게 똑같은 질문 내용을 가지고 지금 현재와 향후 2년에 대한 생각을 묻는 질문들이 있습니다.
#
# 이 두가지의 질문을 비교하면서 생각의 변화가 있는지에 대해 분석을 해보도록 하겠습니다.

# %% [markdown]
# 우리는 처음에 캐글러들이 개인정보에 대한 분석을 하면서 그래프를 함수로 만들었습니다.
#
# 이번 분석에서는 두개의 그래프를 비교해서 분석을 하기 때문에 두가지 그래프를 한번에 그려주는 함수를 만들고자 합니다.
#
# 우리가 계속해서 사용했던 **plot_multiple_qno** 함수를 살짝 변경해서 사용하도록 하겠습니다.

# %%
def plot_multiple_qno_2(qno1,qno2):
  multiple_choice_answer_1 = table_multiple_qno(qno1)
  multiple_choice_answer_2 = table_multiple_qno(qno2)

  fig, ax = plt.subplots(nrows=2)
  fig.set_size_inches(10,12)
  plt.subplots_adjust(wspace=0.3, hspace=0.3) # subplots 간격 새롭게 조절해주는 기능
  
  sns.barplot(data=multiple_choice_answer_1, y=multiple_choice_answer_1.index,
              x="count", palette="Blues_r",ax=ax[0]).set_title(question_title_qno(qno1))
  sns.barplot(data=multiple_choice_answer_2, y=multiple_choice_answer_2.index,
              x="count", palette="Reds_r",ax=ax[1]).set_title(question_title_qno(qno2))

# %% [markdown]
# 다음과 같이  fig, ax 옵션을 사용해서 그래프를 여러개 그릴 수 있습니다.

# %% [markdown]
# ### Q26 cloud computing platforms

# %%
plt.figure(figsize=(18,4))

plot_multiple_qno_2("Q26_A","Q26_B")

# %% [markdown]
# 클라우드 컴퓨팅에 관한 질문입니다.
#
# 현재는 AWS, GCP에 익숙해져 있는 사람들이 많고 다음으로 사용하지 않는 사람들이 많이 있습니다.
#
# 하지만 2년후에는 Microsotf Azure에 익숙해지길 원하는 사람들이 많다는 결과가 나왔습니다.

# %% [markdown]
# ### Q27 cloud computing products

# %%
plot_multiple_qno_2("Q27_A","Q27_B")

# %% [markdown]
# 클라우드 컴퓨터 제품에 관한 질문입니다.
#
# 현재는 Amazon EC2, Google Cloud Compute Engine, AWS Lambda 순으로 많이 사용을 하고 있습니다.
#
# 2년후에도 순위에서는 차기아 많이 없었습니다. 하지만 현재는 사용을 하고 있지 않는 사람들이 많지만 앞으로는 사용을 해보고 싶은 사람들이 많다는 것을 알 수 있었습니다.

# %% [markdown]
# ### Q28 machine learning products

# %%
plot_multiple_qno_2("Q28_A","Q28_B")

# %% [markdown]
# 머신러닝 제품에 관한 질문입니다.
#
# 현재는 사용하지 않는 사람들이 많은 결과가 나오고 다음으로는 구글 클라우드 제품을 사용하는 사람들이 많았습니다.
#
# 2년후 결과를 보면 사람들이 머신러닝 제품을 사용해보는것에 관심이 많다는 것을 알 수 있습니다.
#
# 순위를 보니 구글 제품이 상위권을 많이 차지하는 것으로 보아 구글 제품에 사람들이 관심이 많고 선호한다는 것을 알 수 있습니다.

# %% [markdown]
# ### Q29 data products

# %%
plot_multiple_qno_2("Q29_A","Q29_B")

# %% [markdown]
# 빅데이터 제품에 관한 질문입니다.
#
# 현재는 SQL, 즉 관계형 데이터 베이스 종류를 많이 사용 하고 있습니다.
#
# 2년후 결과를 보니 사람들이 MongDB에 관심이 많은 것 같습니다.

# %% [markdown]
# ### Q31 business intelligence

# %%
plot_multiple_qno_2("Q31_A","Q31_B")

# %% [markdown]
# business intelligence에 관한 질문입니다.
#
# 현재는 사용을 하지 않는 사람들이 가장 많았습니다. 사용하고 있는 사람들 중에서는 Tableau를 가장 많이 사용한다는 결과가 나왔습니다. 그뒤로는 Power BI, Data Studio 등이 있었습니다.
#
# 2년후에는 사람들이 Tableau를 많이 사용해보고 싶다는 결과가 나왔습니다.

# %% [markdown]
# ### Q33 AutoML tools

# %%
plot_multiple_qno_2("Q33_A","Q33_B")

# %% [markdown]
# AutoML을 어디에 사용하고 있는지에 관한 질문입니다.
#
# 현재는 사용을 하지 않고 있는 사람들이 굉장히 많았습니다. 사용하고 있는 사람들 중에서는 모델 선택, 하이퍼파라미터 튜닝등에 사용하는 사람들이 많다는 결과가 나왔습니다.
#
# 2년후에는 사람들이 모델 선택을 하는데 사용하고 싶어한다는 결과가 나왔고 현재에서는 순위가 낮았던 피처 엔지니어링 및 선택을 하는데 사용하고 싶어하는 결과가 나왔습니다.

# %% [markdown]
# ### Q34 automated machine learning tools (or partial AutoML tools)

# %%
plot_multiple_qno_2("Q34_A","Q34_B")

# %% [markdown]
# AutoML에서 주로 사용하고 있는 tool에 관한 질문입니다.
#
# 현재는 사용하지 않는 사람들이 많았습니다. 사용하고 있는 사람들 중에서는 Auto-Sklearn, Auto-Kears 등이 상위권에 있었습니다.
#
# 2년후 결과를 보니 현재와는 별다른 차이가 없었습니다.

# %% [markdown]
# ### Q35 Do you use any tools to help manage machine learning experiments?

# %%
plot_multiple_qno_2("Q35_A","Q35_B")

# %% [markdown]
# 머신러닝을 사용을 하면서 어떠한 toll에 도움을 받고 있는지에 관한 질문입니다.
#
# 현재는 사용을 하지 않는 사람들이 많았고 사용하고 있는 사람들 중에서는 TensorBoard를 사용하고 있는 사람들이 많았습니다.
#
# 2년후에도 현재에서 가장 인기 있었던 TensorBord를 사용하고 있는 사람들이 많았습니다. 그리고 계획이 없는 사람들도 많았습니다.
