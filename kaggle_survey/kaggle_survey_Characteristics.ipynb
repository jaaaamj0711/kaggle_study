# %% [markdown]
# <a href="https://colab.research.google.com/github/jaaaamj0711/kaggle_study/blob/master/kaggle_survey/kaggle_survey_Characteristics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 kaggle survey 2020 (Characteristics of the Kaggler)

# %% [markdown]
# ## 💻 분석을 통한 인사이트 찾기

# %% [markdown]
# #### Q6 For how many years have you been writing code and/or programming?

# %%
plot_by_qno("Q6")

# %% [markdown]
# Q6은 캐글 사용자의 코드 및 프로그램 사용기간에 관한 질문입니다.
#
# 주로 1~5년 사이의 사용자들이 많았습니다.

# %% [markdown]
# #### Q7 What programming languages do you use on a regular basis? (Select all that apply)

# %%
plot_by_qno("Q7")

# %% [markdown]
# Q7은 캐글 사용자들이 주로 사용하는 프로그래밍 언어에 관한 질문입니다.
#
# 예상대로 파이썬이 가장 많았고 다음으로 R이 많을 줄 알았는데 SQL이 2위를 차지했습니다.

# %%
question_title_qno("Q8")
# Out:
# 'What programming language would you recommend an aspiring data scientist to learn first? - Selected Choice'

# %% [markdown]
# #### Q8 What programming language would you recommend an aspiring data scientist to learn first? - Selected Choice

# %%
plot_by_qno("Q8")

# %% [markdown]
# Q8은 데이터 과학을 배우는데 추천하는 언어에 관한 질문입니다.
#
# 역시나 파이썬이 압도적으로 많습니다.

# %% [markdown]
# #### Q9 Which of the following integrated development environments (IDE's) do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q9")

# %% [markdown]
# Q8은 IDE 즉 개발 환경에 관한 질문입니다.
#
# 역시 주피터 노트북이 많았고 다음으로 VSCode, 파이참, R등이 있었습니다.

# %% [markdown]
# #### Q10 Which of the following hosted notebook products do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q10")

# %% [markdown]
# Q10은 호스팅된 노트북 중 어떤 것을 사용하는지에 관한 질문입니다.
#
# 코랩이 가장 많았고, 다음으로 캐글 노트북입니다. 아무래도 캐글 사용자들을 대상으로 설문을 진행했기 때문에 이러한 결과가 나온 것 같습니다.

# %% [markdown]
# #### Q11 What type of computing platform do you use most often for your data science projects? - Selected Choice

# %%
plot_by_qno("Q11")

# %% [markdown]
# Q11은 프로젝트에 주로 사용하는 플랫폼에 관한 질문입니다.
#
# 개인컴퓨트,  클라우드 플랫폼, 딥러닝 워크스테이선 순으로 나왔습니다.

# %% [markdown]
# #### Q12 Which types of specialized hardware do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q12")

# %% [markdown]
# Q12는 정기적으로 사용하는 하드웨어에 관한 질문입니다.
#
# GPU가 1위이고 사용하지 않는 사람들이 많다는 결과가 나왔습니다.

# %% [markdown]
# #### Q13 Approximately how many times have you used a TPU (tensor processing unit)?

# %%
plot_by_qno("Q13")

# %% [markdown]
# 다음은 TPU 사용 횟수에 관한 질문입니다.
#
# 사용하지 않은 사람들이 많다는 결과가 나왔습니다.

# %% [markdown]
# #### Q14 What data visualization libraries or tools do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q14")

# %% [markdown]
# Q14는 사용하는 시각화 라이브러리에 관한 질문입니다.
#
# 역시 유명한 라이브러리인 Matplotlib과 Seaborn 상위권에 있었습니다.

# %% [markdown]
# #### Q15 For how many years have you used machine learning methods?

# %%
plot_by_qno("Q15")

# %% [markdown]
# Q15는 머신러닝 사용 기간에 관한 질문입니다.
#
# 1년 이하가 가장 많았습니다.

# %% [markdown]
# #### Q16 Which of the following machine learning frameworks do you use on a regular basis? (Select all that apply)

# %%
plot_by_qno("Q16")

# %% [markdown]
# Q16은 정기적으로 사용하는 머신러닝 프레임워크에 관한 질문입니다.
#
# 예상했던대로 Scikit-learn, TensorFlow, Keras 등이 있었습니다.

# %% [markdown]
# #### Q17 Which of the following ML algorithms do you use on a regular basis? (Select all that apply):

# %%
plot_by_qno("Q17")

# %% [markdown]
# Q17은 정기적으로 사용하는 머신러닝 알고리즘에 관한 질문입니다.
#
# 회귀분석, 의사결정나무 랜덤포레스트이 상위권에 있었고 딥러닝 종류에서는 CNN이 가장 많았습니다.

# %% [markdown]
# #### Q18 Which categories of computer vision methods do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q18")

# %% [markdown]
# Q18은 컴퓨터비전을 어떠한 종류로 많이 쓰는지에 관한 질문입니다.
#
# 이미지 분류로 많이 사용한다는 결과가 나왔습니다.

# %% [markdown]
# #### Q19 Which of the following natural language processing (NLP) methods do you use on a regular basis?  (Select all that apply)

# %%
plot_by_qno("Q19")

# %% [markdown]
# Q19는 자연어 처리 방법에 관한 질문입니다.
#
# 워드 임베딩이 가장 많고, 인코더 디코더 그리고 트렌스포머 모델이 상위권에 있었습니다.

# %% [markdown]
# #### Q30 Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often? - Selected Choice

# %%
plot_by_qno("Q30")

# %% [markdown]
# 가장 많이 사용하는 빅데이터 제품에 관한 질문입니다.
#
# MySQL을 가장 많이 사용하고 있습니다. 결과를 주로 보니 주로 관계형 데이터 베이스를 많이 사용한다는 결과가 나왔습니다.

# %% [markdown]
# #### Q36 Where do you publicly share or deploy your data analysis or machine learning applications? (Select all that apply)

# %%
plot_by_qno("Q36")

# %% [markdown]
# 데이터 분석이나 머신러닝에 관한 public으로 공유를 할때  주로 어디에 공유를 하는지에 관한 질문입니다.
#
# 캐글러들은 Github에 많이 공유를 한다는 결과가 나왔고 공유를 하지 않는 사람들도 많이 있었습니다. 다음으로는 Kaggle, Colab등이 있었습니다.

# %% [markdown]
# #### Q37 On which platforms have you begun or completed data science courses? (Select all that apply)

# %%
plot_by_qno("Q37")

# %% [markdown]
# 데이터 과학 코스를 주로 어디에서 수강을 하는지에 관한 질문입니다.
#
# 코세라가 가장 많고 다음으로 캐글, 유데미 등이 있었습니다.

# %% [markdown]
# #### Q38 What is the primary tool that you use at work or school to analyze data? (Include text response) - Selected Choice

# %%
plot_by_qno("Q38")

# %% [markdown]
# 직장이나 학교에서 데이터를 분석하기 위해 주로 사용하는 tool에 관한 질문입니다.
#
# 로컬환경에서 가장 많이 사용을 하고 엑셀, 구글시트도 많이 사용을 하는 결과가 나왔습니다.

# %%
plot_by_qno("Q39")

# %% [markdown]
# 데이터 과학에 과학 주제에 관해서 가장 선호하는 미디어에 관한 질문입니다.
#
# 캐글이 가장 많았고 유튜브, 블로그, 트위터 등이 있었습니다.
