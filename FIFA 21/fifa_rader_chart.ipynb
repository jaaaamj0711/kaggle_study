# %%
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# %%
# Load data
data = pd.read_csv('./players_21.csv')
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  \
# 0        170         72   Argentina         FC Barcelona
# ...

# %%
select_player =  data[data.short_name.isin(['H. Son', 'Cristiano Ronaldo', 'R. Lewandowski', 'K. De Bruyne'])]
select_player = select_player[['short_name', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']]
select_player
# Out:
#            short_name  pace  shooting  passing  dribbling  defending  physic
# 1   Cristiano Ronaldo  89.0      93.0     81.0       89.0       35.0    77.0
# 3      R. Lewandowski  78.0      91.0     78.0       85.0       43.0    82.0
# 5        K. De Bruyne  76.0      86.0     93.0       88.0       64.0    78.0
# 46             H. Son  88.0      86.0     80.0       87.0       43.0    69.0

# %%
select_player.style.set_caption('Select player')
# Out:
# <style  type="text/css" >
# </style><table id="T_1d7ed_" ><caption>Select player</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >short_name</th>        <th class="col_heading level0 col1" >pace</th>        <th class="col_heading level0 col2" >shooting</th>        <th class="col_heading level0 col3" >passing</th>        <th class="col_heading level0 col4" >dribbling</th>        <th class="col_heading level0 col5" >defending</th>        <th class="col_heading level0 col6" >physic</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d7ed_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1d7ed_row0_col0" class="data row0 col0" >Cristiano Ronaldo</td>
#                         <td id="T_1d7ed_row0_col1" class="data row0 col1" >89.000000</td>
#                         <td id="T_1d7ed_row0_col2" class="data row0 col2" >93.000000</td>
# ...

# %%
# style
select_player.style.set_caption('Top players')\
          .set_table_styles([{'selector': 'tr:hover','props': [('background-color', '#0080ff')]}])\
          .set_precision(0)\
          .background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_a9ff4_ tr:hover {
#           background-color: #0080ff;
#     }#T_a9ff4_row0_col1,#T_a9ff4_row0_col2,#T_a9ff4_row0_col4,#T_a9ff4_row1_col6,#T_a9ff4_row2_col3,#T_a9ff4_row2_col5{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_a9ff4_row0_col3{
#             background-color:  #d3eecd;
#             color:  #000000;
#         }#T_a9ff4_row0_col5,#T_a9ff4_row1_col3,#T_a9ff4_row1_col4,#T_a9ff4_row2_col1,#T_a9ff4_row2_col2,#T_a9ff4_row3_col2,#T_a9ff4_row3_col6{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_a9ff4_row0_col6{
#             background-color:  #45ad5f;
#             color:  #000000;
#         }#T_a9ff4_row1_col1{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_a9ff4_row1_col2{
#             background-color:  #2c944c;
#             color:  #000000;
#         }#T_a9ff4_row1_col5,#T_a9ff4_row3_col5{
# ...

# %%
def create_polarcharts(
    stats: list,
    color: str,
    img_link: str,
    name_one: str,
    name_two: str
):
    '''
    The function accepts the following arguments:
    
        stats - takes a list of numeric values of characteristics
        color - takes the color of the lines in the diagram
        img_link - accepts a link to an image of a football player
        name_one - takes the name of the footballer
        name_two - accepts any additional text
    
    '''
    # Determine the number of rows and columns
    fig = make_subplots(rows=1, cols=2, 
                        # We indicate the types of graphs in each block
                        specs=[[{'type': 'xy'}, {"type": "polar"}]], 
                        # Setting the width of each column
                        column_widths=[0.5, 0.5])  
    
    # Create a Polar Chart
    fig.add_trace(go.Scatterpolar(
                     # Passing numeric parameters
                     r=stats,
                     # Passing parameter names
                     theta=['Pace', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physic', 'Pace'],
                     # Setting the fill parameter
                     fill='toself',
                     # Specify the signature on hover
                     hovertemplate='<b>%{theta}</b>' + f'<b>: '+'%{r}',
                     # Specify a caption for the legend
                     name='',
                     # Specifying the line color
                     line=dict(color=color)),
                     # Specify line and column numbers
                     row=1, col=2)
    
    # Add an image to the chart
    fig.layout.images = [dict(
               # Passing a link to the image
               source=img_link,
               # Specify the position of the image along the x-axis
               x=0.1, 
               # Specify the position of the image along the y-axis
               y=0.5,
               # Setting the size of the chart
               sizex=1, 
               sizey=1.6,
               # Setting the position along the x-axis
               xanchor="center", 
               # Setting the y-axis position
               yanchor="middle",
               # Place the image under the chart
               layer="below"
                             )
                        ]

    fig.update_layout(
        # Set the name of the chart
        title=f'<b>{name_one}</b><br><sub>{name_two}</sub>',
        # Setting the background color
        paper_bgcolor="rgb(223, 223, 223)",
        # Setting the chart theme
        template='xgridoff',
        # Passing chart parameters
        polar=dict(
             # Background color
             bgcolor="rgb(223, 223, 223)",
             # Adding a line with numeric divisions
             radialaxis=dict(
                        # Displaying the line
                        visible = True,
                        # Set the range of divisions
                        range = [0, 100]
                            )
                   ), 
        # Passing the parameters to the font
        font=dict(
                  # Font type
                  family='Arials',
                  # Font size
                  size=14,
                  # Font color
                  color='Black'
                 )
    )

    # Displaying the graph
    fig.show()

# %%
create_polarcharts([85, 92, 91, 95, 38, 65, 85], 
                   'MidnightBlue',
                   'https://cdn.pngsumo.com/lionel-messi-2018-png-10-by-flashdsg-lionel-messi-png-1024_2048.png',     
                   'L. Messi',
                   'Forward in FC Barcelona')
# Out:
# <div>                            <div id="d69ee373-ac9e-453a-90db-2c9e3d5d8285" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d69ee373-ac9e-453a-90db-2c9e3d5d8285")) {                    Plotly.newPlot(                        "d69ee373-ac9e-453a-90db-2c9e3d5d8285",                        [{"fill": "toself", "hovertemplate": "<b>%{theta}</b><b>: %{r}", "line": {"color": "MidnightBlue"}, "name": "", "r": [85, 92, 91, 95, 38, 65, 85], "subplot": "polar", "theta": ["Pace", "Shooting", "Passing", "Dribbling", "Defending", "Physic", "Pace"], "type": "scatterpolar"}],                        {"font": {"color": "Black", "family": "Arials", "size": 14}, "images": [{"layer": "below", "sizex": 1, "sizey": 1.6, "source": "https://cdn.pngsumo.com/lionel-messi-2
# ...

# %%
create_polarcharts([76, 86, 93, 88, 64, 78, 76], 
                   'LightSkyBlue',
                   'https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/d063371c-efae-4f82-92fd-c1513e8755bb/dd79wki-24ee4df7-772a-494f-8263-a2cf0c9ad6ca.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJ1cm46YXBwOiIsImlzcyI6InVybjphcHA6Iiwib2JqIjpbW3sicGF0aCI6IlwvZlwvZDA2MzM3MWMtZWZhZS00ZjgyLTkyZmQtYzE1MTNlODc1NWJiXC9kZDc5d2tpLTI0ZWU0ZGY3LTc3MmEtNDk0Zi04MjYzLWEyY2YwYzlhZDZjYS5wbmcifV1dLCJhdWQiOlsidXJuOnNlcnZpY2U6ZmlsZS5kb3dubG9hZCJdfQ.gI0llRzl4eXdCnXJN9aJET5ZENoc8WFcRFFO4c66aMU',
                   'K. De Bruyne',
                   'Midfielder in Manchester City')
# Out:
# <div>                            <div id="3d67b7ea-9362-46d6-8142-feed595e2008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d67b7ea-9362-46d6-8142-feed595e2008")) {                    Plotly.newPlot(                        "3d67b7ea-9362-46d6-8142-feed595e2008",                        [{"fill": "toself", "hovertemplate": "<b>%{theta}</b><b>: %{r}", "line": {"color": "LightSkyBlue"}, "name": "", "r": [76, 86, 93, 88, 64, 78, 76], "subplot": "polar", "theta": ["Pace", "Shooting", "Passing", "Dribbling", "Defending", "Physic", "Pace"], "type": "scatterpolar"}],                        {"font": {"color": "Black", "family": "Arials", "size": 14}, "images": [{"layer": "below", "sizex": 1, "sizey": 1.6, "source": "https://images-wixmp-ed30a86b8c4ca8877
# ...

# %%
create_polarcharts([78, 91, 78, 85, 43, 82, 78], 
                   'Red',
                   'https://cdn.pngsumo.com/robert-lewandowski-by-dianjay-on-deviantart-robert-lewandowski-png-736_1024.png',
                   'R. Lewandowski',
                   'Forward in FC Bayern München')
# Out:
# <div>                            <div id="4b673982-6d47-4764-9d70-a4eab6199e17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b673982-6d47-4764-9d70-a4eab6199e17")) {                    Plotly.newPlot(                        "4b673982-6d47-4764-9d70-a4eab6199e17",                        [{"fill": "toself", "hovertemplate": "<b>%{theta}</b><b>: %{r}", "line": {"color": "Red"}, "name": "", "r": [78, 91, 78, 85, 43, 82, 78], "subplot": "polar", "theta": ["Pace", "Shooting", "Passing", "Dribbling", "Defending", "Physic", "Pace"], "type": "scatterpolar"}],                        {"font": {"color": "Black", "family": "Arials", "size": 14}, "images": [{"layer": "below", "sizex": 1, "sizey": 1.6, "source": "https://cdn.pngsumo.com/robert-lewandowski-by-d
# ...

# %%
# https://www.kaggle.com/ivannatarov/plotly-for-beginners-polar-charts-image/
