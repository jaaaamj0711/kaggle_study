# %% [markdown]
# # 문제 정의
# **목표**: 통신사를 가입한 고객이 통신사를 변경할지를 예측하는 문제

# %% [markdown]
# **- (1)** 어떤 요소와 이탈고객과 영향이 있을까?
#
# **- (2)** 그 요소들이 이탈고객에게 어떠한 영향을 줄까??

# %% [markdown]
# #### 변수 설명
# |변수|설명|
# |------|---|
# |state|미국 고객 거주 주|
# |account_length|고객이 현재 통신사와 함께한 월 수|
# |area_code|3자리 지역 코드|
# |international_plan|고객이 국제적인 계획을 가지고 있는지 여부|
# |voice_mail_plan|고객이 음성 메일 계획을 가지고 있는지 여부|
# |number_vmail_messages|숫자, 음성 메시지 수|
# |total_day_minutes|통화 총 분(낮)|
# |total_day_calls|통화 총 수(낮)|
# |total_day_charge|통화 총 요금(낮)|
# |total_eve_minutes|통화 총 분(저녁)|
# |total_eve_calls|통화 총 수(저녁)|
# |total_eve_charge|통화 총 요금(저녁)|
# |total_night_minutes|통화 총 분(밤)|
# |total_night_calls|통화 총 수(밤)|
# |total_night_charge|통화 총 요금(밤)|
# |total_intl_minutes|통화 총 분(해외)|
# |total_intl_calls|통화 총 수(해외)|
# |total_intl_charge|통화 총 요금(해외)|
# |number_customer_service_calls|숫자의 고객 서비스에 대한 통화 수|
# |churn|타겟 값|

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")

# %%
train.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# 1             41.38              121.2              110             10.30
# 2             50.90               61.9               88              5.26
# 3             28.34              148.3              122             12.61
# 4             37.09              348.5              108             29.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                254.4                103               11.45
# 1                162.6                104                7.32
# 2                196.9                 89                8.86
# 3                186.9                121                8.41
# 4                212.6                118                9.57
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                13.7                 3               3.70
# 1                12.2                 5               3.29
# 2                 6.6                 7               1.78
# 3                10.1                 3               2.73
# 4                 7.5                 7               2.03
#
#    number_customer_service_calls churn
# 0                              1    no
# 1                              0    no
# 2                              2    no
# 3                              3    no
# 4                              3    no

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 20 columns):
# state                            4250 non-null object
# account_length                   4250 non-null int64
# area_code                        4250 non-null object
# international_plan               4250 non-null object
# voice_mail_plan                  4250 non-null object
# number_vmail_messages            4250 non-null int64
# total_day_minutes                4250 non-null float64
# total_day_calls                  4250 non-null int64
# total_day_charge                 4250 non-null float64
# total_eve_minutes                4250 non-null float64
# total_eve_calls                  4250 non-null int64
# total_eve_charge                 4250 non-null float64
# total_night_minutes              4250 non-null float64
# total_night_calls                4250 non-null int64
# total_night_charge               4250 non-null float64
# total_intl_minutes               4250 non-null float64
# total_intl_calls                 4250 non-null int64
# total_intl_charge                4250 non-null float64
# number_customer_service_calls    4250 non-null int64
# churn                            4250 non-null object
# dtypes: float64(8), int64(7), object(5)
# memory usage: 664.1+ KB

# %% [markdown]
# - 모든 변수에서 결측값을 존재하지 않는다.
# - int형 변수는 7개
# - float형 변수는 8개
# - object형 변수는 5개

# %% [markdown]
# # EDA

# %%
train["churn"].value_counts()
# Out:
# no     3652
# yes     598
# Name: churn, dtype: int64

# %% [markdown]
# ## **이탈 고객 특징 파악하기**

# %% [markdown]
# ### 통신사 변경 유무에 따른 거주 주 비교

# %%
churn_yes = train[train['churn']=="yes"]
churn_no = train[train['churn']=="no"]

# %%
churn_yes.head()
# Out:
#    state  account_length      area_code international_plan voice_mail_plan  \
# 8     IN              65  area_code_415                 no              no
# 12    NY             161  area_code_415                 no              no
# 17    CO              77  area_code_408                 no              no
# 26    AZ              12  area_code_408                 no              no
# 32    MD             135  area_code_408                yes             yes
#
#     number_vmail_messages  total_day_minutes  total_day_calls  \
# 8                       0              129.1              137
# 12                      0              332.9               67
# 17                      0               62.4               89
# 26                      0              249.6              118
# 32                     41              173.1               85
#
#     total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 8              21.95              228.5               83             19.42
# 12             56.59              317.8               97             27.01
# 17             10.61              169.9              121             14.44
# 26             42.43              252.4              119             21.45
# 32             29.43              203.9              107             17.33
#
#     total_night_minutes  total_night_calls  total_night_charge  \
# 8                 208.8                111                9.40
# 12                160.6                128                7.23
# 17                209.6                 64                9.43
# 26                280.2                 90               12.61
# 32                122.2                 78                5.50
#
#     total_intl_minutes  total_intl_calls  total_intl_charge  \
# 8                 12.7                 6               3.43
# 12                 5.4                 9               1.46
# 17                 5.7                 6               1.54
# 26                11.8                 3               3.19
# 32                14.6                15               3.94
#
#     number_customer_service_calls churn
# 8                               4   yes
# 12                              4   yes
# 17                              5   yes
# 26                              1   yes
# 32                              0   yes

# %%
churn_yes["state"].value_counts()
# Out:
# NJ    26
# MD    19
# WV    19
# MN    19
# TX    19
# WA    18
# MT    17
# NV    17
# OK    16
# ME    16
# NY    16
# KS    15
# MI    15
# MS    15
# OR    15
# CT    15
# MA    14
# SC    14
# IN    13
# AL    13
# DE    13
# OH    12
# KY    12
# TN    12
# UT    12
# ID    12
# SD    11
# AR    11
# NM    10
# MO    10
# VT    10
# CA    10
# NH    10
# WY    10
# FL     9
# CO     9
# PA     8
# DC     8
# NC     7
# AZ     7
# LA     7
# WI     7
# IA     7
# GA     7
# IL     6
# RI     6
# ND     6
# VA     5
# NE     5
# AK     4
# HI     4
# Name: state, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))


sns.countplot(x = 'state',
              data = churn_yes,
              ax = ax[0],
              order = churn_yes['state'].value_counts()[:10].index)
# plt.xticks(rotation=90)
ax[0].set_title('churn_yes state')
ax[0].set_ylabel('count')


sns.countplot(x = 'state',
              data = churn_no,
              ax = ax[1],
              order = churn_no['state'].value_counts()[:10].index)
ax[1].set_title('churn_no state')
ax[1].set_ylabel('count')
plt.show()

# %% [markdown]
# - **통신사를 바꾼 고객**이 거주하는 상위 주는 New Jersey, West Virginia, Minnesota 등이다.
# - **통신사를 바꾸지 않은 고객**이 거주하는 상위 주는 West Virginia, Virginia , Idaho 등이다.
#
# 통시사 변경 유무에 따라 고객들이 주로 거주하는 주에는 차이가 있다.

# %%
f, ax = plt.subplots(4, 2, figsize=(25, 15))

sns.distplot(churn_yes['total_day_minutes'],ax = ax[0,0])
sns.distplot(churn_no['total_day_minutes'],ax = ax[0,1])

sns.distplot(churn_yes['total_eve_minutes'],ax = ax[1,0])
sns.distplot(churn_no['total_eve_minutes'],ax = ax[1,1])

sns.distplot(churn_yes['total_night_minutes'],ax = ax[2,0])
sns.distplot(churn_no['total_night_minutes'],ax = ax[2,1])

sns.distplot(churn_yes['total_intl_minutes'],ax = ax[3,0])
sns.distplot(churn_no['total_intl_minutes'],ax = ax[3,1])

# %%
f, ax = plt.subplots(4, 2, figsize=(25, 15))

sns.distplot(churn_yes['total_day_calls'],ax = ax[0,0],color="green")
sns.distplot(churn_no['total_day_calls'],ax = ax[0,1],color="green")

sns.distplot(churn_yes['total_eve_calls'],ax = ax[1,0],color="green")
sns.distplot(churn_no['total_eve_calls'],ax = ax[1,1],color="green")

sns.distplot(churn_yes['total_night_calls'],ax = ax[2,0],color="green")
sns.distplot(churn_no['total_night_calls'],ax = ax[2,1],color="green")

sns.distplot(churn_yes['total_intl_calls'],ax = ax[3,0],color="green")
sns.distplot(churn_no['total_intl_calls'],ax = ax[3,1],color="green")

# %%
f, ax = plt.subplots(4, 2, figsize=(25, 15))

sns.distplot(churn_yes['total_day_charge'],ax = ax[0,0],color="purple")
sns.distplot(churn_no['total_day_charge'],ax = ax[0,1],color="purple")

sns.distplot(churn_yes['total_eve_charge'],ax = ax[1,0],color="purple")
sns.distplot(churn_no['total_eve_charge'],ax = ax[1,1],color="purple")

sns.distplot(churn_yes['total_night_charge'],ax = ax[2,0],color="purple")
sns.distplot(churn_no['total_night_charge'],ax = ax[2,1],color="purple")

sns.distplot(churn_yes['total_intl_charge'],ax = ax[3,0],color="purple")
sns.distplot(churn_no['total_intl_charge'],ax = ax[3,1],color="purple")

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## object형 타입 변경하기

# %%
train.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# 1             41.38              121.2              110             10.30
# 2             50.90               61.9               88              5.26
# 3             28.34              148.3              122             12.61
# 4             37.09              348.5              108             29.62
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                254.4                103               11.45
# 1                162.6                104                7.32
# 2                196.9                 89                8.86
# 3                186.9                121                8.41
# 4                212.6                118                9.57
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                13.7                 3               3.70
# 1                12.2                 5               3.29
# 2                 6.6                 7               1.78
# 3                10.1                 3               2.73
# 4                 7.5                 7               2.03
#
#    number_customer_service_calls churn
# 0                              1    no
# 1                              0    no
# 2                              2    no
# 3                              3    no
# 4                              3    no

# %%
le = LabelEncoder()
train["state"] = le.fit_transform(train['state'])
test["state"] = le.fit_transform(test['state'])

# %%
train["area_code"] = train["area_code"].str.slice(10,)
test["area_code"] = test["area_code"].str.slice(10,)
#train["area_code"].head()

# %%
train["area_code"] = le.fit_transform(train['area_code'])
test["area_code"] = le.fit_transform(test['area_code'])

# %%
train = pd.get_dummies(train, columns = ['international_plan'])
test = pd.get_dummies(test, columns = ['international_plan'])

# %%
train = pd.get_dummies(train, columns = ['voice_mail_plan'])
test = pd.get_dummies(test, columns = ['voice_mail_plan'])

# %% [markdown]
# # 모델링

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 25 columns):
# state                            4250 non-null int32
# account_length                   4250 non-null int64
# area_code                        4250 non-null int32
# number_vmail_messages            4250 non-null int64
# total_day_minutes                4250 non-null float64
# total_day_calls                  4250 non-null int64
# total_day_charge                 4250 non-null float64
# total_eve_minutes                4250 non-null float64
# total_eve_calls                  4250 non-null int64
# total_eve_charge                 4250 non-null float64
# total_night_minutes              4250 non-null float64
# total_night_calls                4250 non-null int64
# total_night_charge               4250 non-null float64
# total_intl_minutes               4250 non-null float64
# total_intl_calls                 4250 non-null int64
# total_intl_charge                4250 non-null float64
# number_customer_service_calls    4250 non-null int64
# churn                            4250 non-null object
# international_plan_no            4250 non-null uint8
# international_plan_yes           4250 non-null uint8
# voice_mail_plan_no               4250 non-null uint8
# voice_mail_plan_yes              4250 non-null uint8
# total_calls                      4250 non-null int64
# total_charge                     4250 non-null float64
# total_minutes                    4250 non-null float64
# dtypes: float64(10), int32(2), int64(8), object(1), uint8(4)
# memory usage: 680.7+ KB

# %%
train.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'churn', 'international_plan_no',
#        'international_plan_yes', 'voice_mail_plan_no', 'voice_mail_plan_yes'],
#       dtype='object')

# %% [markdown]
# ## 입력변수간 상관관계 파악하기

# %%
input_var = ['state', 'account_length', 'area_code', 'number_vmail_messages',
       'total_day_minutes', 'total_day_calls', 'total_day_charge',
       'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
       'total_night_minutes', 'total_night_calls', 'total_night_charge',
       'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
       'number_customer_service_calls','international_plan_no',
       'international_plan_yes', 'voice_mail_plan_no', 'voice_mail_plan_yes']

# %%
corr = train[input_var].corr()

# %%
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col3 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col8 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col9 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col10 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col11 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col12 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col13 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col14 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col15 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col17 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col18 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col19 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row0_col20 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col0 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col3 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col7 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col8 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col9 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col10 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col11 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col12 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col13 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col14 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col15 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col16 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col17 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col18 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col19 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row1_col20 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col3 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col6 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col9 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col10 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col11 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col12 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col13 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col14 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col15 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col16 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_38721ba2_eea6_11ea_bc88_207918fdc879row2_col17 {
#             background-color:  #d9dce1;

# %% [markdown]
# - voice_mail_plan_yes, number_vmail_messages
# - total_night_charge, total_night_minutes
# - ttotal_intl_charge, total_intl_minutes
# **다음과 같이 상관관계가 높은 변수들을 같이 입력하여 예측하면 정확도가 떨어지기 때문에 두개 중 하나를 선택할 필요가 있다**

# %%
train["churn2"] = le.fit_transform(train['churn']) # 상관관계 파악을 위해 변경

# %%
train["number_vmail_messages"].corr(train["churn2"])
# Out:
# -0.1003465278887836

# %%
train["voice_mail_plan_yes"].corr(train["churn2"])
# Out:
# -0.11464257735226924

# %% [markdown]
# **voice_mail_plan_yes 선택**

# %%
train["total_night_charge"].corr(train["churn2"])
# Out:
# 0.04664097076937198

# %%
train["total_night_minutes"].corr(train["churn2"])
# Out:
# 0.046647182635507364

# %% [markdown]
# **total_night_minutes 선택**

# %%
train["total_intl_charge"].corr(train["churn2"])
# Out:
# 0.055176611642417515

# %%
train["total_intl_minutes"].corr(train["churn2"])
# Out:
# 0.05518578653026759

# %% [markdown]
# **total_intl_minutes 선택**

# %%
input_var = ['state', 'account_length', 'area_code',
       'total_day_minutes', 'total_day_calls', 'total_day_charge',
       'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
       'total_night_minutes', 'total_night_calls',
       'total_intl_minutes', 'total_intl_calls', 
       'number_customer_service_calls','international_plan_no',
       'international_plan_yes', 'voice_mail_plan_no', 'voice_mail_plan_yes']

# %% [markdown]
# ## 모델 학습

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(n_estimators=100,learning_rate=0.1)
model.fit(train[input_var],train['churn'])
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %% [markdown]
# ## shape.value

# %%
import shap

# %%
shap_values = shap.TreeExplainer(model).shap_values(train[input_var])

# %%
shap.summary_plot(shap_values,train[input_var],plot_type='bar')

# %% [markdown]
# **상위 6개 변수를 사용**

# %%
input_var = ['total_day_minutes','number_customer_service_calls',
             'international_plan_no','voice_mail_plan_no','total_eve_minutes',
             'total_intl_calls']

# %%
shap.dependence_plot('total_day_minutes',shap_values,train[input_var])

# %%
shap.dependence_plot('number_customer_service_calls',shap_values,train[input_var])

# %%
shap.dependence_plot('international_plan_no',shap_values,train[input_var])

# %%
shap.dependence_plot('voice_mail_plan_no',shap_values,train[input_var])

# %%
shap.dependence_plot('total_eve_minutes',shap_values,train[input_var])

# %%
shap.dependence_plot('total_intl_calls',shap_values,train[input_var])

# %% [raw]
# test["churn"] = xgb.predict(test[input_var])

# %%
test["churn"] = model.predict(test[input_var])

# %%
test['churn'].value_counts()
# Out:
# no     668
# yes     82
# Name: churn, dtype: int64

# %%
test['id']=range(len(test))

# %%
test[['id','churn']].to_csv("./Submission4.csv")

# %%
Image("./score.PNG")
